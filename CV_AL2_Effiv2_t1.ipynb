# %% [markdown]
# <a href="https://colab.research.google.com/github/yiyoungkim/yy/blob/main/CV_AL2_Effiv2_t1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The goal is to solve the fine-grained image classification train the model using hyperparameter tuning, data augmentation, etc., and write a report with a detailed analysis of the results.
#  - Is the problem solved in an appropriate way?
# - Are different hyperparameters and data augmentation used for training and are the results compared and analyzed?
# - Is the use of appropriate visualization tools and experiment tools for your reports?
# e.g., GradCAM, Weight & Biases, etc.

# %%
# !pip install efficientnet_pytorch
# !pip install adamp
# Out:
# Requirement already satisfied: efficientnet_pytorch in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from efficientnet_pytorch) (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->efficientnet_pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->efficientnet_pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->efficientnet_pytorch) (1.3.0)
# Collecting adamp
#   Downloading adamp-0.3.0.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: adamp
#   Building wheel for adamp (setup.py) ... done
#   Created wheel for adamp: filename=adamp-0.3.0-py3-none-any.whl size=5982 sha256=ed979711a0d8af437319274141dc8aec16e22078807489f6ae59f3e7f45a1278
#   Stored in directory: /root/.cache/pip/wheels/c7/ad/0f/b41b1c45b18c66e5eef5d2254415af8055c7e2b0934145157d
# Successfully built adamp
# Installing collected packages: adamp
# Successfully installed adamp-0.3.0

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision.transforms as transforms
from torchvision.transforms import ToTensor,Normalize, RandomHorizontalFlip, Resize
from torch.utils.data import ConcatDataset
from torchvision.transforms import RandAugment

import torchvision.models as models
from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image,ImageFilter,ImageEnhance

# from adabelief_pytorch import AdaBelief
from torch.optim.lr_scheduler import CosineAnnealingLR

from collections import Counter
from torch.utils.data import WeightedRandomSampler

from efficientnet_pytorch import EfficientNet
from adamp import AdamP
# Set random seed
seed = 20
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed)

### GPU Setting ###
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")
print(DEVICE)
# Out:
# cuda

# %%
# !pip install wandb
# import wandb
# wandb.login()

# # Initialize wandb
# wandb.init(project="gpt5")
# config = wandb.config
# config.dropout = 0.01

# %%
### Custom Dataset ###
class CUB2011(Dataset):
  def __init__(self, transform, mode='train'):
    self.transform = transform
    self.mode = mode

    if self.mode == 'train':
      self.image_folder = os.listdir('/content/drive/MyDrive/datasets/train')
    elif self.mode == 'valid':
      self.image_folder = os.listdir('/content/drive/MyDrive/datasets/valid')
    elif self.mode == 'test':
      self.image_folder = os.listdir('/content/drive/MyDrive/datasets/test')

  def __len__(self):
    return len(self.image_folder)

  def __getitem__(self, idx):
    img_path = self.image_folder[idx]
    img = Image.open(os.path.join('/content/drive/MyDrive/datasets', self.mode, img_path)).convert('RGB')
    img = self.transform(img)


    label = img_path.split('_')[-1].split('.')[0]
    label = int(label)
    return (img, label)

# %%
# Geomentric transform + Visual corruptions
class AddGaussianNoise(object):
    def __init__(self, mean=0, std=1, p=0.5):
        self.mean = mean
        self.std = std
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            img_array = np.array(img)
            noise = np.random.normal(self.mean, self.std, img_array.shape)
            noisy_image = np.clip(img_array + noise, 0, 255)  # Clip values to the range [0, 255]
            return Image.fromarray(noisy_image.astype(np.uint8))
        else:
            return img

    def __repr__(self):
        return self.__class__.__name__ + f'(mean={self.mean}, std={self.std}, p={self.p})'


class AdjustContrast(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'

class AdjustBrightness(object):
    def __init__(self, factor=1.0):
        self.factor = factor

    def __call__(self, img):
        enhancer = ImageEnhance.Brightness(img)
        img = enhancer.enhance(self.factor)
        return img

    def __repr__(self):
        return self.__class__.__name__ + f'(factor={self.factor})'


# Mix up
def mixup_data(x, y, alpha=1.0):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size, device=x.device, dtype=torch.long)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
### Data Preprocessing ###
transforms_train_origin = transforms.Compose([transforms.Resize((448,448), Image.BICUBIC),
                                       transforms.ToTensor(),
                                       transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
                                       ])
transforms_test = transforms.Compose([transforms.Resize((448,448), Image.BICUBIC),
                                       transforms.ToTensor(),
                                      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
                                       ])

# Apply RandAugment
transforms_train_rand = transforms.Compose([
    transforms.Resize((448, 448), Image.BICUBIC),
    RandAugment(5,3),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Geomentric transform + Visual corruptions
transforms_train_g_v = transforms.Compose([
    transforms.Resize((448, 448), Image.BICUBIC),
    transforms.RandomResizedCrop(448),
    transforms.RandomHorizontalFlip(0.5),
    transforms.RandomVerticalFlip(0.5),
    transforms.RandomRotation(30),
    AddGaussianNoise(mean=0, std=25, p=0.5),
    AdjustContrast(factor=2.0),
    AdjustBrightness(factor=1.5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


BATCH_SIZE = 8

train_set_origin = CUB2011(mode='train',
                    transform=transforms_train_origin)
val_set = CUB2011(mode='valid',
                  transform=transforms_test)
test_set = CUB2011(mode='test',
                  transform=transforms_test)

# Duplicate original data for data augmentation
train_set_augmented = CUB2011(mode='train', transform=transforms_train_rand)
train_set_augmented2 = CUB2011(mode='train',transform=transforms_train_g_v)

# train_loader = DataLoader(train_set_origin,batch_size=BATCH_SIZE,shuffle=True)

# # Add mixed-up images to the train_loader
# train_set_mixup = []
# for input, target in train_loader:
#     mixed_input, target_a, target_b, lam = mixup_data(input, target, alpha=1.0)
#     train_set_mixup.append((mixed_input, target_a, target_b, lam))
# train_set_mixup = transforms.Compose([transforms.Resize((448,448), Image.BICUBIC),
#                                        transforms.ToTensor(),
#                                       transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#                                        ])
# train_set_mixup = CUB2011(mode='train', transform=train_set_mixup)



# Concatenate the datasets to create a new training dataset
train_set_combined = ConcatDataset([train_set_origin,train_set_augmented2])

print('Num of each dataset: ',len(train_set_combined),len(val_set),len(test_set))
# print('Num of each dataset: ',len(train_set_origin),len(train_set_augmented), len(train_set_augmented2), len(train_set_mixup))


#-----------------------------------------------------------------------
# DataLoader class creates mini-batches for training deep learning models
# DataLoader divides the entire dataset into batches of size BATCH_SIZE
# train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
train_loader = DataLoader(train_set_combined, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set,batch_size=BATCH_SIZE,shuffle=False)
test_loader = DataLoader(test_set,batch_size=BATCH_SIZE,shuffle=False)

print("Loaded dataloader")
# Out:
# Num of each dataset:  4720 296 298
# Loaded dataloader

# %%
# !pip install --upgrade adabelief-pytorch
# Out:
# Collecting adabelief-pytorch
#   Downloading adabelief_pytorch-0.2.1-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from adabelief-pytorch) (2.1.0+cu118)
# Collecting colorama>=0.4.0 (from adabelief-pytorch)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: tabulate>=0.7 in /usr/local/lib/python3.10/dist-packages (from adabelief-pytorch) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->adabelief-pytorch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->adabelief-pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->adabelief-pytorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->adabelief-pytorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->adabelief-pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->adabelief-pytorch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->adabelief-pytorch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.0->adabelief-pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.0->adabelief-pytorch) (1.3.0)
# Installing collected packages: colorama, adabelief-pytorch
# Successfully installed adabelief-pytorch-0.2.1 colorama-0.4.6

# %%
### Model / Optimizer ###
EPOCH = 30

lr = 0.0001

model = torch.hub.load('hankyul2/EfficientNetV2-pytorch', 'efficientnet_v2_s', pretrained=True, nclass=50)

# ResNet-50의 마지막 fully connected 레이어를 변경하여 새로운 클래스 수에 맞게 설정
# num_features = model.fc.in_features
# model.fc = nn.Sequential(
#     nn.Linear(num_features, 512),
#     nn.ReLU(),
#     nn.Dropout(0.5),
#     nn.Linear(512, 50)  # 클래스 수에 맞게 설정
# )
model.to(DEVICE)

# Apply Weight Decay: Prevent overfitting with L2 regularization
# optimizer = AdaBelief(model.parameters(), lr=lr, betas=(0.9, 0.999), eps=1e-16, weight_decouple=True, rectify=True)
# optimizer = AdaBelief(model.parameters(), lr=lr, betas=(0.9, 0.999), eps=1e-16, weight_decouple=True, rectify=True, weight_decay=1e-5)
optimizer = AdamP(model.parameters(),lr=lr)
# Initialize Cosine Annealing LR Scheduler

dataset_size = len(train_set_combined) # Size of the training dataset
T_max = dataset_size / BATCH_SIZE  # Number of epochs for one cycle
scheduler = CosineAnnealingLR(optimizer, T_max=T_max, eta_min=0.001)

print("Created a learning model and optimizer")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/hankyul2/EfficientNetV2-pytorch/zipball/main" to /root/.cache/torch/hub/main.zip
# Created a learning model and optimizer

# %%
print(model)
# Out:
# EfficientNetV2(
#   (stem): ConvBNAct(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SiLU()
#   )
#   (blocks): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(24, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (3): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (4): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (5): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (6): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(48, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (7): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (8): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (9): MBConv(
#       (block): Sequential(
#         (fused): ConvBNAct(
#           (0): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (fused_point_wise): ConvBNAct(
#           (0): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (10): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (11): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (12): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (13): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (14): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (15): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (16): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(768, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 768, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (17): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (18): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (19): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (20): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (21): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (22): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (23): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (24): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (25): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (26): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (27): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (28): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (29): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (30): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (31): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (32): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (33): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (34): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (35): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (36): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (37): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (38): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#     (39): MBConv(
#       (block): Sequential(
#         (linear_bottleneck): ConvBNAct(
#           (0): Conv2d(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (depth_wise): ConvBNAct(
#           (0): Conv2d(1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#           (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU()
#         )
#         (se): SEUnit(
#           (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc1): Conv2d(1536, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 1536, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (act2): Sigmoid()
#         )
#         (point_wise): ConvBNAct(
#           (0): Conv2d(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): Identity()
#         )
#       )
#       (stochastic_path): StochasticDepth()
#     )
#   )
#   (head): Sequential(
#     (bottleneck): ConvBNAct(
#       (0): Conv2d(256, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU()
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (dropout): Dropout(p=0.1, inplace=True)
#     (classifier): Linear(in_features=1280, out_features=50, bias=True)
#   )
# )

# %%
### Train/Evaluation ###
def train(model,train_loader,optimizer,epoch):
  model.train()
  for i,(image,target) in enumerate(train_loader):
    image,target = image.to(DEVICE),target.to(DEVICE)
    output = model(image)
    optimizer.zero_grad()

    #  # Label Smoothing
    # target_smooth = torch.zeros_like(output).scatter(1, target.unsqueeze(1), 1)
    # target_smooth = target_smooth * (1 - 0.11) + 0.11 / target_smooth.size(1)

    train_loss = F.cross_entropy(output,target).to(DEVICE)

    train_loss.backward()
    optimizer.step()

    # Implement gradient clipping
    torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.25)  # You can adjust the 'max_norm' parameter as needed

    # Update the scheduler
    scheduler.step()

    if i%10 ==0:
      print(
          f'Train Epoch: {epoch} [{i}/{len(train_loader)}]\tloss: {train_loss.item():6f}')

  return train_loss

def evaluate(model,val_loader):
  model.eval()
  eval_loss = 0
  correct = 0
  with torch.no_grad():
    for i,(image,target) in enumerate(val_loader):
      image,target = image.to(DEVICE),target.to(DEVICE)
      output = model(image)

      eval_loss += F.cross_entropy(output,target, reduction='sum').item()
      pred = output.max(1,keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()

  eval_loss /= len(val_loader.dataset)
  eval_accuracy = 100*correct / len(val_loader.dataset)
  return eval_loss,eval_accuracy

# %%
#### Mian ###
start = time.time()
best = 0

train_losses = []  # 훈련 손실을 저장할 목록
val_losses = []    # 검증 손실을 저장할 목록
val_accuracys = []

# 디렉토리 생성
os.makedirs('./best_model', exist_ok=True)

for epoch in range(EPOCH):
  train_loss = train(model,train_loader,optimizer,epoch)
  val_loss,val_accuracy = evaluate(model,val_loader)

  # # Log metrics to wandb
  # wandb.log({"loss": loss.item()})

  # 훈련 및 검증 손실을 목록에 추가
  train_losses.append(train_loss)
  val_losses.append(val_loss)

  # Save best model
  if val_accuracy > best:
    best = val_accuracy
    torch.save(model.state_dict(),"./best_model.pth")

  val_accuracys.append(val_accuracy)
  print(f"[{epoch}]Validation Loss: {val_loss:.4f},Accuracy: {val_accuracy:.4f}%")

# Test result
test_loss,test_accuracy = evaluate(model,test_loader)
print(f'[FINAL] Test Loss: {test_loss:.4f},Accuracy: {test_accuracy:.4f}%')

end = time.time()
elasped_time = end - start

print("Best Accuracy: ",best)
print(
    f"Elasped Time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
print(
    f"time: {int(elasped_time/3600)}h, {int(elasped_time/60)}m, {int(elasped_time%60)}s")
# Out:
# Train Epoch: 0 [0/590]	loss: 3.931400
# Train Epoch: 0 [10/590]	loss: 3.905694
# Train Epoch: 0 [20/590]	loss: 3.930751
# Train Epoch: 0 [30/590]	loss: 3.900127
# Train Epoch: 0 [40/590]	loss: 3.879567
# Train Epoch: 0 [50/590]	loss: 3.842381
# Train Epoch: 0 [60/590]	loss: 3.732921
# Train Epoch: 0 [70/590]	loss: 3.853221
# Train Epoch: 0 [80/590]	loss: 3.839936
# Train Epoch: 0 [90/590]	loss: 3.690416
# Train Epoch: 0 [100/590]	loss: 3.580322
# Train Epoch: 0 [110/590]	loss: 3.724669
# Train Epoch: 0 [120/590]	loss: 3.246482
# Train Epoch: 0 [130/590]	loss: 3.372931
# Train Epoch: 0 [140/590]	loss: 3.401510
# Train Epoch: 0 [150/590]	loss: 2.854623
# Train Epoch: 0 [160/590]	loss: 3.289502
# Train Epoch: 0 [170/590]	loss: 3.069608
# Train Epoch: 0 [180/590]	loss: 3.106890
# Train Epoch: 0 [190/590]	loss: 2.676423
# Train Epoch: 0 [200/590]	loss: 2.707323
# Train Epoch: 0 [210/590]	loss: 2.724361
# Train Epoch: 0 [220/590]	loss: 3.099902
# Train Epoch: 0 [230/590]	loss: 2.993847
# Train Epoch: 0 [240/590]	loss: 2.451727
# Train Epoch: 0 [250/590]	loss: 2.429160
# Train Epoch: 0 [260/590]	loss: 2.323520
# Train Epoch: 0 [270/590]	loss: 2.421153
# Train Epoch: 0 [280/590]	loss: 3.006289
# Train Epoch: 0 [290/590]	loss: 2.736135
# Train Epoch: 0 [300/590]	loss: 1.811084
# Train Epoch: 0 [310/590]	loss: 2.799627
# Train Epoch: 0 [320/590]	loss: 2.369650
# Train Epoch: 0 [330/590]	loss: 2.176995
# Train Epoch: 0 [340/590]	loss: 1.930026
# Train Epoch: 0 [350/590]	loss: 3.014224
# Train Epoch: 0 [360/590]	loss: 2.982971
# Train Epoch: 0 [370/590]	loss: 3.081820
# Train Epoch: 0 [380/590]	loss: 4.269955
# Train Epoch: 0 [390/590]	loss: 3.422596
# Train Epoch: 0 [400/590]	loss: 2.556886
# Train Epoch: 0 [410/590]	loss: 2.678926
# Train Epoch: 0 [420/590]	loss: 3.772573
# Train Epoch: 0 [430/590]	loss: 2.690842
# Train Epoch: 0 [440/590]	loss: 3.180925
# Train Epoch: 0 [450/590]	loss: 3.233093
# Train Epoch: 0 [460/590]	loss: 2.256711
# Train Epoch: 0 [470/590]	loss: 3.152664
# Train Epoch: 0 [480/590]	loss: 1.954127
# Train Epoch: 0 [490/590]	loss: 3.344039
# Train Epoch: 0 [500/590]	loss: 3.069034
# Train Epoch: 0 [510/590]	loss: 3.028476
# Train Epoch: 0 [520/590]	loss: 2.520945
# Train Epoch: 0 [530/590]	loss: 2.439065
# Train Epoch: 0 [540/590]	loss: 3.032938
# Train Epoch: 0 [550/590]	loss: 3.449349
# Train Epoch: 0 [560/590]	loss: 3.094601
# Train Epoch: 0 [570/590]	loss: 2.599149
# Train Epoch: 0 [580/590]	loss: 2.081301
# [0]Validation Loss: 2.1075,Accuracy: 37.8378%
# Train Epoch: 1 [0/590]	loss: 2.368346
# Train Epoch: 1 [10/590]	loss: 2.601077
# Train Epoch: 1 [20/590]	loss: 2.340387
# Train Epoch: 1 [30/590]	loss: 2.097357
# Train Epoch: 1 [40/590]	loss: 1.944938
# Train Epoch: 1 [50/590]	loss: 2.173987
# Train Epoch: 1 [60/590]	loss: 2.727062
# Train Epoch: 1 [70/590]	loss: 2.242131
# Train Epoch: 1 [80/590]	loss: 2.200542
# Train Epoch: 1 [90/590]	loss: 1.488844
# Train Epoch: 1 [100/590]	loss: 2.300908
# Train Epoch: 1 [110/590]	loss: 1.962876
# Train Epoch: 1 [120/590]	loss: 1.781055
# Train Epoch: 1 [130/590]	loss: 2.706772
# Train Epoch: 1 [140/590]	loss: 2.705791
# Train Epoch: 1 [150/590]	loss: 2.456399
# Train Epoch: 1 [160/590]	loss: 2.801589
# Train Epoch: 1 [170/590]	loss: 3.565183
# Train Epoch: 1 [180/590]	loss: 2.537669
# Train Epoch: 1 [190/590]	loss: 2.406026
# Train Epoch: 1 [200/590]	loss: 2.075704
# Train Epoch: 1 [210/590]	loss: 1.722793
# Train Epoch: 1 [220/590]	loss: 2.223086
# Train Epoch: 1 [230/590]	loss: 1.236488
# Train Epoch: 1 [240/590]	loss: 2.009536
# Train Epoch: 1 [250/590]	loss: 1.720862
# Train Epoch: 1 [260/590]	loss: 1.448645
# Train Epoch: 1 [270/590]	loss: 0.832266
# Train Epoch: 1 [280/590]	loss: 2.795490
# Train Epoch: 1 [290/590]	loss: 0.960352
# Train Epoch: 1 [300/590]	loss: 2.639746
# Train Epoch: 1 [310/590]	loss: 2.019277
# Train Epoch: 1 [320/590]	loss: 2.168011
# Train Epoch: 1 [330/590]	loss: 1.034225
# Train Epoch: 1 [340/590]	loss: 1.520591
# Train Epoch: 1 [350/590]	loss: 2.011638
# Train Epoch: 1 [360/590]	loss: 1.855734
# Train Epoch: 1 [370/590]	loss: 1.700553
# Train Epoch: 1 [380/590]	loss: 0.852193
# Train Epoch: 1 [390/590]	loss: 1.534793
# Train Epoch: 1 [400/590]	loss: 1.970326
# Train Epoch: 1 [410/590]	loss: 1.022482
# Train Epoch: 1 [420/590]	loss: 1.311485
# Train Epoch: 1 [430/590]	loss: 1.783668
# Train Epoch: 1 [440/590]	loss: 1.997905
# Train Epoch: 1 [450/590]	loss: 1.146642
# Train Epoch: 1 [460/590]	loss: 1.149911
# Train Epoch: 1 [470/590]	loss: 2.280451
# Train Epoch: 1 [480/590]	loss: 1.580779
# Train Epoch: 1 [490/590]	loss: 1.414922
# Train Epoch: 1 [500/590]	loss: 1.389914
# Train Epoch: 1 [510/590]	loss: 1.318084
# Train Epoch: 1 [520/590]	loss: 1.605855
# Train Epoch: 1 [530/590]	loss: 1.837076
# Train Epoch: 1 [540/590]	loss: 0.646488
# Train Epoch: 1 [550/590]	loss: 0.995052
# Train Epoch: 1 [560/590]	loss: 0.988634
# Train Epoch: 1 [570/590]	loss: 1.105718
# Train Epoch: 1 [580/590]	loss: 1.083407
# [1]Validation Loss: 0.5765,Accuracy: 80.7432%
# Train Epoch: 2 [0/590]	loss: 1.053924
# Train Epoch: 2 [10/590]	loss: 0.776115
# Train Epoch: 2 [20/590]	loss: 0.561339
# Train Epoch: 2 [30/590]	loss: 2.176846
# Train Epoch: 2 [40/590]	loss: 1.080793
# Train Epoch: 2 [50/590]	loss: 1.171078
# Train Epoch: 2 [60/590]	loss: 0.876884
# Train Epoch: 2 [70/590]	loss: 1.033164
# Train Epoch: 2 [80/590]	loss: 0.577647
# Train Epoch: 2 [90/590]	loss: 1.489593
# Train Epoch: 2 [100/590]	loss: 1.140487
# Train Epoch: 2 [110/590]	loss: 0.948132
# Train Epoch: 2 [120/590]	loss: 0.914689
# Train Epoch: 2 [130/590]	loss: 0.736879
# Train Epoch: 2 [140/590]	loss: 0.651339
# Train Epoch: 2 [150/590]	loss: 0.983651
# Train Epoch: 2 [160/590]	loss: 0.931060
# Train Epoch: 2 [170/590]	loss: 1.064370
# Train Epoch: 2 [180/590]	loss: 1.531103
# Train Epoch: 2 [190/590]	loss: 0.911452
# Train Epoch: 2 [200/590]	loss: 0.820762
# Train Epoch: 2 [210/590]	loss: 0.968574
# Train Epoch: 2 [220/590]	loss: 2.009448
# Train Epoch: 2 [230/590]	loss: 0.582478
# Train Epoch: 2 [240/590]	loss: 0.998496
# Train Epoch: 2 [250/590]	loss: 1.086780
# Train Epoch: 2 [260/590]	loss: 0.748191
# Train Epoch: 2 [270/590]	loss: 1.505213
# Train Epoch: 2 [280/590]	loss: 0.503597
# Train Epoch: 2 [290/590]	loss: 0.737059
# Train Epoch: 2 [300/590]	loss: 2.226273
# Train Epoch: 2 [310/590]	loss: 1.008350
# Train Epoch: 2 [320/590]	loss: 0.811870
# Train Epoch: 2 [330/590]	loss: 1.084028
# Train Epoch: 2 [340/590]	loss: 0.714606
# Train Epoch: 2 [350/590]	loss: 0.944421
# Train Epoch: 2 [360/590]	loss: 1.631691
# Train Epoch: 2 [370/590]	loss: 2.006251
# Train Epoch: 2 [380/590]	loss: 2.189987
# Train Epoch: 2 [390/590]	loss: 1.125588
# Train Epoch: 2 [400/590]	loss: 2.535736
# Train Epoch: 2 [410/590]	loss: 1.090464
# Train Epoch: 2 [420/590]	loss: 1.127005
# Train Epoch: 2 [430/590]	loss: 1.082003
# Train Epoch: 2 [440/590]	loss: 0.861461
# Train Epoch: 2 [450/590]	loss: 2.370140
# Train Epoch: 2 [460/590]	loss: 1.435442
# Train Epoch: 2 [470/590]	loss: 1.431517
# Train Epoch: 2 [480/590]	loss: 1.377819
# Train Epoch: 2 [490/590]	loss: 1.731867
# Train Epoch: 2 [500/590]	loss: 1.775620
# Train Epoch: 2 [510/590]	loss: 1.901471
# Train Epoch: 2 [520/590]	loss: 1.533601
# Train Epoch: 2 [530/590]	loss: 1.753755
# Train Epoch: 2 [540/590]	loss: 1.025554
# Train Epoch: 2 [550/590]	loss: 2.670957
# Train Epoch: 2 [560/590]	loss: 2.616594
# Train Epoch: 2 [570/590]	loss: 2.671979
# Train Epoch: 2 [580/590]	loss: 3.167875
# [2]Validation Loss: 1.6726,Accuracy: 57.0946%
# Train Epoch: 3 [0/590]	loss: 1.434426
# Train Epoch: 3 [10/590]	loss: 1.035210
# Train Epoch: 3 [20/590]	loss: 2.387460
# Train Epoch: 3 [30/590]	loss: 1.520268
# Train Epoch: 3 [40/590]	loss: 2.714073
# Train Epoch: 3 [50/590]	loss: 1.505856
# Train Epoch: 3 [60/590]	loss: 0.833637
# Train Epoch: 3 [70/590]	loss: 1.912268
# Train Epoch: 3 [80/590]	loss: 2.711066
# Train Epoch: 3 [90/590]	loss: 1.024795
# Train Epoch: 3 [100/590]	loss: 1.858847
# Train Epoch: 3 [110/590]	loss: 1.287591
# Train Epoch: 3 [120/590]	loss: 1.715629
# Train Epoch: 3 [130/590]	loss: 2.785619
# Train Epoch: 3 [140/590]	loss: 1.502259
# Train Epoch: 3 [150/590]	loss: 2.146247
# Train Epoch: 3 [160/590]	loss: 1.124003
# Train Epoch: 3 [170/590]	loss: 1.430746
# Train Epoch: 3 [180/590]	loss: 1.178493
# Train Epoch: 3 [190/590]	loss: 0.855739
# Train Epoch: 3 [200/590]	loss: 1.324866
# Train Epoch: 3 [210/590]	loss: 1.022399
# Train Epoch: 3 [220/590]	loss: 1.370684
# Train Epoch: 3 [230/590]	loss: 0.646835
# Train Epoch: 3 [240/590]	loss: 1.281334
# Train Epoch: 3 [250/590]	loss: 2.138279
# Train Epoch: 3 [260/590]	loss: 1.198074
# Train Epoch: 3 [270/590]	loss: 1.496783
# Train Epoch: 3 [280/590]	loss: 1.849383
# Train Epoch: 3 [290/590]	loss: 1.275377
# Train Epoch: 3 [300/590]	loss: 1.562609
# Train Epoch: 3 [310/590]	loss: 1.849605
# Train Epoch: 3 [320/590]	loss: 1.591033
# Train Epoch: 3 [330/590]	loss: 2.100308
# Train Epoch: 3 [340/590]	loss: 0.875296
# Train Epoch: 3 [350/590]	loss: 1.470534
# Train Epoch: 3 [360/590]	loss: 0.440009
# Train Epoch: 3 [370/590]	loss: 1.228014
# Train Epoch: 3 [380/590]	loss: 1.423257
# Train Epoch: 3 [390/590]	loss: 1.319370
# Train Epoch: 3 [400/590]	loss: 1.615829
# Train Epoch: 3 [410/590]	loss: 1.378051
# Train Epoch: 3 [420/590]	loss: 0.966226
# Train Epoch: 3 [430/590]	loss: 0.400245
# Train Epoch: 3 [440/590]	loss: 0.851227
# Train Epoch: 3 [450/590]	loss: 1.012450
# Train Epoch: 3 [460/590]	loss: 0.520029
# Train Epoch: 3 [470/590]	loss: 0.916780
# Train Epoch: 3 [480/590]	loss: 1.224269
# Train Epoch: 3 [490/590]	loss: 1.469590
# Train Epoch: 3 [500/590]	loss: 1.079476
# Train Epoch: 3 [510/590]	loss: 1.015922
# Train Epoch: 3 [520/590]	loss: 1.706360
# Train Epoch: 3 [530/590]	loss: 0.813617
# Train Epoch: 3 [540/590]	loss: 1.457217
# Train Epoch: 3 [550/590]	loss: 0.576629
# Train Epoch: 3 [560/590]	loss: 0.704672
# Train Epoch: 3 [570/590]	loss: 0.532130
# Train Epoch: 3 [580/590]	loss: 1.374753
# [3]Validation Loss: 0.4119,Accuracy: 86.8243%
# Train Epoch: 4 [0/590]	loss: 1.810693
# Train Epoch: 4 [10/590]	loss: 1.010152
# Train Epoch: 4 [20/590]	loss: 0.660261
# Train Epoch: 4 [30/590]	loss: 0.213729
# Train Epoch: 4 [40/590]	loss: 1.357739
# Train Epoch: 4 [50/590]	loss: 0.798548
# Train Epoch: 4 [60/590]	loss: 0.449089
# Train Epoch: 4 [70/590]	loss: 1.364614
# Train Epoch: 4 [80/590]	loss: 0.616134
# Train Epoch: 4 [90/590]	loss: 0.946173
# Train Epoch: 4 [100/590]	loss: 0.837867
# Train Epoch: 4 [110/590]	loss: 1.628183
# Train Epoch: 4 [120/590]	loss: 0.729137
# Train Epoch: 4 [130/590]	loss: 0.651350
# Train Epoch: 4 [140/590]	loss: 0.597353
# Train Epoch: 4 [150/590]	loss: 0.775693
# Train Epoch: 4 [160/590]	loss: 0.595287
# Train Epoch: 4 [170/590]	loss: 1.312465
# Train Epoch: 4 [180/590]	loss: 0.451758
# Train Epoch: 4 [190/590]	loss: 0.588113
# Train Epoch: 4 [200/590]	loss: 0.650789
# Train Epoch: 4 [210/590]	loss: 1.129009
# Train Epoch: 4 [220/590]	loss: 1.382959
# Train Epoch: 4 [230/590]	loss: 1.051311
# Train Epoch: 4 [240/590]	loss: 0.881637
# Train Epoch: 4 [250/590]	loss: 0.819930
# Train Epoch: 4 [260/590]	loss: 0.980279
# Train Epoch: 4 [270/590]	loss: 0.456964
# Train Epoch: 4 [280/590]	loss: 1.484308
# Train Epoch: 4 [290/590]	loss: 1.081221
# Train Epoch: 4 [300/590]	loss: 0.710798
# Train Epoch: 4 [310/590]	loss: 1.003573
# Train Epoch: 4 [320/590]	loss: 0.506241
# Train Epoch: 4 [330/590]	loss: 0.849486
# Train Epoch: 4 [340/590]	loss: 1.566852
# Train Epoch: 4 [350/590]	loss: 0.639290
# Train Epoch: 4 [360/590]	loss: 1.099220
# Train Epoch: 4 [370/590]	loss: 0.997836
# Train Epoch: 4 [380/590]	loss: 0.744910
# Train Epoch: 4 [390/590]	loss: 0.746442
# Train Epoch: 4 [400/590]	loss: 0.681582
# Train Epoch: 4 [410/590]	loss: 0.539426
# Train Epoch: 4 [420/590]	loss: 0.498283
# Train Epoch: 4 [430/590]	loss: 1.429217
# Train Epoch: 4 [440/590]	loss: 1.143545
# Train Epoch: 4 [450/590]	loss: 1.929090
# Train Epoch: 4 [460/590]	loss: 1.039383
# Train Epoch: 4 [470/590]	loss: 2.197149
# Train Epoch: 4 [480/590]	loss: 1.026447
# Train Epoch: 4 [490/590]	loss: 2.790481
# Train Epoch: 4 [500/590]	loss: 0.798774
# Train Epoch: 4 [510/590]	loss: 1.381534
# Train Epoch: 4 [520/590]	loss: 2.205347
# Train Epoch: 4 [530/590]	loss: 1.665525
# Train Epoch: 4 [540/590]	loss: 2.383283
# Train Epoch: 4 [550/590]	loss: 1.182090
# Train Epoch: 4 [560/590]	loss: 2.620359
# Train Epoch: 4 [570/590]	loss: 1.248677
# Train Epoch: 4 [580/590]	loss: 1.069885
# [4]Validation Loss: 1.0132,Accuracy: 69.5946%
# Train Epoch: 5 [0/590]	loss: 0.942192
# Train Epoch: 5 [10/590]	loss: 0.627810
# Train Epoch: 5 [20/590]	loss: 1.289617
# Train Epoch: 5 [30/590]	loss: 1.433894
# Train Epoch: 5 [40/590]	loss: 1.505760
# Train Epoch: 5 [50/590]	loss: 2.029720
# Train Epoch: 5 [60/590]	loss: 2.699397
# Train Epoch: 5 [70/590]	loss: 2.018024
# Train Epoch: 5 [80/590]	loss: 0.621736
# Train Epoch: 5 [90/590]	loss: 1.441935
# Train Epoch: 5 [100/590]	loss: 0.367124
# Train Epoch: 5 [110/590]	loss: 0.666240
# Train Epoch: 5 [120/590]	loss: 1.401568
# Train Epoch: 5 [130/590]	loss: 1.325055
# Train Epoch: 5 [140/590]	loss: 0.588243
# Train Epoch: 5 [150/590]	loss: 1.477947
# Train Epoch: 5 [160/590]	loss: 1.528882
# Train Epoch: 5 [170/590]	loss: 0.289551
# Train Epoch: 5 [180/590]	loss: 1.994770
# Train Epoch: 5 [190/590]	loss: 1.483859
# Train Epoch: 5 [200/590]	loss: 0.904914
# Train Epoch: 5 [210/590]	loss: 1.573063
# Train Epoch: 5 [220/590]	loss: 0.742259
# Train Epoch: 5 [230/590]	loss: 0.308718
# Train Epoch: 5 [240/590]	loss: 0.328168
# Train Epoch: 5 [250/590]	loss: 1.501894
# Train Epoch: 5 [260/590]	loss: 0.933063
# Train Epoch: 5 [270/590]	loss: 1.883561
# Train Epoch: 5 [280/590]	loss: 1.531081
# Train Epoch: 5 [290/590]	loss: 0.893341
# Train Epoch: 5 [300/590]	loss: 1.071110
# Train Epoch: 5 [310/590]	loss: 0.908784
# Train Epoch: 5 [320/590]	loss: 1.156816
# Train Epoch: 5 [330/590]	loss: 0.296384
# Train Epoch: 5 [340/590]	loss: 0.936621
# Train Epoch: 5 [350/590]	loss: 0.405424
# Train Epoch: 5 [360/590]	loss: 0.561155
# Train Epoch: 5 [370/590]	loss: 0.937944
# Train Epoch: 5 [380/590]	loss: 2.161551
# Train Epoch: 5 [390/590]	loss: 1.215646
# Train Epoch: 5 [400/590]	loss: 1.543842
# Train Epoch: 5 [410/590]	loss: 0.170172
# Train Epoch: 5 [420/590]	loss: 0.608881
# Train Epoch: 5 [430/590]	loss: 1.103083
# Train Epoch: 5 [440/590]	loss: 0.185784
# Train Epoch: 5 [450/590]	loss: 1.681998
# Train Epoch: 5 [460/590]	loss: 0.247496
# Train Epoch: 5 [470/590]	loss: 1.601164
# Train Epoch: 5 [480/590]	loss: 1.426665
# Train Epoch: 5 [490/590]	loss: 1.108226
# Train Epoch: 5 [500/590]	loss: 1.203642
# Train Epoch: 5 [510/590]	loss: 0.337292
# Train Epoch: 5 [520/590]	loss: 1.269783
# Train Epoch: 5 [530/590]	loss: 0.187852
# Train Epoch: 5 [540/590]	loss: 1.812737
# Train Epoch: 5 [550/590]	loss: 1.622711
# Train Epoch: 5 [560/590]	loss: 0.813388
# Train Epoch: 5 [570/590]	loss: 0.583662
# Train Epoch: 5 [580/590]	loss: 0.505433
# [5]Validation Loss: 0.3986,Accuracy: 89.8649%
# Train Epoch: 6 [0/590]	loss: 0.656369
# Train Epoch: 6 [10/590]	loss: 0.476686
# Train Epoch: 6 [20/590]	loss: 0.532078
# Train Epoch: 6 [30/590]	loss: 0.358480
# Train Epoch: 6 [40/590]	loss: 0.650672
# Train Epoch: 6 [50/590]	loss: 0.610189
# Train Epoch: 6 [60/590]	loss: 1.543621
# Train Epoch: 6 [70/590]	loss: 0.723162
# Train Epoch: 6 [80/590]	loss: 0.962328
# Train Epoch: 6 [90/590]	loss: 1.112008
# Train Epoch: 6 [100/590]	loss: 2.826195
# Train Epoch: 6 [110/590]	loss: 0.061752
# Train Epoch: 6 [120/590]	loss: 0.871144
# Train Epoch: 6 [130/590]	loss: 0.211165
# Train Epoch: 6 [140/590]	loss: 0.464574
# Train Epoch: 6 [150/590]	loss: 0.486156
# Train Epoch: 6 [160/590]	loss: 1.374594
# Train Epoch: 6 [170/590]	loss: 0.606840
# Train Epoch: 6 [180/590]	loss: 1.607382
# Train Epoch: 6 [190/590]	loss: 0.850481
# Train Epoch: 6 [200/590]	loss: 1.425223
# Train Epoch: 6 [210/590]	loss: 0.217381
# Train Epoch: 6 [220/590]	loss: 1.017062
# Train Epoch: 6 [230/590]	loss: 0.228161
# Train Epoch: 6 [240/590]	loss: 0.638090
# Train Epoch: 6 [250/590]	loss: 0.924300
# Train Epoch: 6 [260/590]	loss: 0.187767
# Train Epoch: 6 [270/590]	loss: 0.761874
# Train Epoch: 6 [280/590]	loss: 0.763521
# Train Epoch: 6 [290/590]	loss: 0.420094
# Train Epoch: 6 [300/590]	loss: 0.476420
# Train Epoch: 6 [310/590]	loss: 0.604052
# Train Epoch: 6 [320/590]	loss: 1.685888
# Train Epoch: 6 [330/590]	loss: 1.106489
# Train Epoch: 6 [340/590]	loss: 0.936163
# Train Epoch: 6 [350/590]	loss: 0.726543
# Train Epoch: 6 [360/590]	loss: 1.965928
# Train Epoch: 6 [370/590]	loss: 0.552328
# Train Epoch: 6 [380/590]	loss: 1.139300
# Train Epoch: 6 [390/590]	loss: 1.135252
# Train Epoch: 6 [400/590]	loss: 1.121498
# Train Epoch: 6 [410/590]	loss: 0.600838
# Train Epoch: 6 [420/590]	loss: 0.977969
# Train Epoch: 6 [430/590]	loss: 0.743562
# Train Epoch: 6 [440/590]	loss: 0.429768
# Train Epoch: 6 [450/590]	loss: 1.980187
# Train Epoch: 6 [460/590]	loss: 0.664849
# Train Epoch: 6 [470/590]	loss: 2.082740
# Train Epoch: 6 [480/590]	loss: 0.998546
# Train Epoch: 6 [490/590]	loss: 1.570799
# Train Epoch: 6 [500/590]	loss: 0.348973
# Train Epoch: 6 [510/590]	loss: 1.595780
# Train Epoch: 6 [520/590]	loss: 1.664330
# Train Epoch: 6 [530/590]	loss: 1.036216
# Train Epoch: 6 [540/590]	loss: 2.249801
# Train Epoch: 6 [550/590]	loss: 2.159280
# Train Epoch: 6 [560/590]	loss: 2.355549
# Train Epoch: 6 [570/590]	loss: 0.867389
# Train Epoch: 6 [580/590]	loss: 1.453866
# [6]Validation Loss: 1.2191,Accuracy: 67.5676%
# Train Epoch: 7 [0/590]	loss: 0.481195
# Train Epoch: 7 [10/590]	loss: 3.517188
# Train Epoch: 7 [20/590]	loss: 1.961931
# Train Epoch: 7 [30/590]	loss: 1.237547
# Train Epoch: 7 [40/590]	loss: 2.315566
# Train Epoch: 7 [50/590]	loss: 0.870371
# Train Epoch: 7 [60/590]	loss: 1.963393
# Train Epoch: 7 [70/590]	loss: 0.481133
# Train Epoch: 7 [80/590]	loss: 0.982509
# Train Epoch: 7 [90/590]	loss: 0.592586
# Train Epoch: 7 [100/590]	loss: 1.354814
# Train Epoch: 7 [110/590]	loss: 1.689484
# Train Epoch: 7 [120/590]	loss: 2.501796
# Train Epoch: 7 [130/590]	loss: 1.193341
# Train Epoch: 7 [140/590]	loss: 0.363222
# Train Epoch: 7 [150/590]	loss: 0.689593
# Train Epoch: 7 [160/590]	loss: 1.449190
# Train Epoch: 7 [170/590]	loss: 1.618833
# Train Epoch: 7 [180/590]	loss: 1.225646
# Train Epoch: 7 [190/590]	loss: 2.262176
# Train Epoch: 7 [200/590]	loss: 0.954613
# Train Epoch: 7 [210/590]	loss: 0.893548
# Train Epoch: 7 [220/590]	loss: 0.636699
# Train Epoch: 7 [230/590]	loss: 1.218262
# Train Epoch: 7 [240/590]	loss: 0.737402
# Train Epoch: 7 [250/590]	loss: 1.236584
# Train Epoch: 7 [260/590]	loss: 1.188282
# Train Epoch: 7 [270/590]	loss: 0.367875
# Train Epoch: 7 [280/590]	loss: 0.986264
# Train Epoch: 7 [290/590]	loss: 0.658022
# Train Epoch: 7 [300/590]	loss: 0.686223
# Train Epoch: 7 [310/590]	loss: 1.630860
# Train Epoch: 7 [320/590]	loss: 0.806326
# Train Epoch: 7 [330/590]	loss: 1.061835
# Train Epoch: 7 [340/590]	loss: 1.168054
# Train Epoch: 7 [350/590]	loss: 1.532730
# Train Epoch: 7 [360/590]	loss: 0.988198
# Train Epoch: 7 [370/590]	loss: 0.335828
# Train Epoch: 7 [380/590]	loss: 0.888573
# Train Epoch: 7 [390/590]	loss: 0.220791
# Train Epoch: 7 [400/590]	loss: 0.220380
# Train Epoch: 7 [410/590]	loss: 0.256446
# Train Epoch: 7 [420/590]	loss: 1.435333
# Train Epoch: 7 [430/590]	loss: 0.726598
# Train Epoch: 7 [440/590]	loss: 0.674187
# Train Epoch: 7 [450/590]	loss: 0.683478
# Train Epoch: 7 [460/590]	loss: 0.071170
# Train Epoch: 7 [470/590]	loss: 0.716866
# Train Epoch: 7 [480/590]	loss: 1.747762
# Train Epoch: 7 [490/590]	loss: 0.846214
# Train Epoch: 7 [500/590]	loss: 0.566128
# Train Epoch: 7 [510/590]	loss: 0.295287
# Train Epoch: 7 [520/590]	loss: 0.316627
# Train Epoch: 7 [530/590]	loss: 0.515965
# Train Epoch: 7 [540/590]	loss: 0.434310
# Train Epoch: 7 [550/590]	loss: 1.114239
# Train Epoch: 7 [560/590]	loss: 0.749447
# Train Epoch: 7 [570/590]	loss: 0.470370
# Train Epoch: 7 [580/590]	loss: 0.127388
# [7]Validation Loss: 0.3967,Accuracy: 89.1892%
# Train Epoch: 8 [0/590]	loss: 0.937821
# Train Epoch: 8 [10/590]	loss: 0.188613
# Train Epoch: 8 [20/590]	loss: 0.178236
# Train Epoch: 8 [30/590]	loss: 1.033544
# Train Epoch: 8 [40/590]	loss: 0.051111
# Train Epoch: 8 [50/590]	loss: 0.733493
# Train Epoch: 8 [60/590]	loss: 0.301037
# Train Epoch: 8 [70/590]	loss: 0.387481
# Train Epoch: 8 [80/590]	loss: 0.622292
# Train Epoch: 8 [90/590]	loss: 0.235159
# Train Epoch: 8 [100/590]	loss: 0.285294
# Train Epoch: 8 [110/590]	loss: 0.726973
# Train Epoch: 8 [120/590]	loss: 0.146194
# Train Epoch: 8 [130/590]	loss: 0.133972
# Train Epoch: 8 [140/590]	loss: 0.643515
# Train Epoch: 8 [150/590]	loss: 0.692611
# Train Epoch: 8 [160/590]	loss: 0.460705
# Train Epoch: 8 [170/590]	loss: 0.998259
# Train Epoch: 8 [180/590]	loss: 0.477073
# Train Epoch: 8 [190/590]	loss: 1.064982
# Train Epoch: 8 [200/590]	loss: 0.780684
# Train Epoch: 8 [210/590]	loss: 0.487684
# Train Epoch: 8 [220/590]	loss: 0.459951
# Train Epoch: 8 [230/590]	loss: 0.430403
# Train Epoch: 8 [240/590]	loss: 0.359558
# Train Epoch: 8 [250/590]	loss: 1.621159
# Train Epoch: 8 [260/590]	loss: 0.483938
# Train Epoch: 8 [270/590]	loss: 1.016201
# Train Epoch: 8 [280/590]	loss: 1.010645
# Train Epoch: 8 [290/590]	loss: 0.664387
# Train Epoch: 8 [300/590]	loss: 0.814510
# Train Epoch: 8 [310/590]	loss: 0.542131
# Train Epoch: 8 [320/590]	loss: 0.730496
# Train Epoch: 8 [330/590]	loss: 0.373303
# Train Epoch: 8 [340/590]	loss: 1.582865
# Train Epoch: 8 [350/590]	loss: 0.759445
# Train Epoch: 8 [360/590]	loss: 0.482241
# Train Epoch: 8 [370/590]	loss: 1.195198
# Train Epoch: 8 [380/590]	loss: 0.926281
# Train Epoch: 8 [390/590]	loss: 0.978723
# Train Epoch: 8 [400/590]	loss: 0.905409
# Train Epoch: 8 [410/590]	loss: 0.167551
# Train Epoch: 8 [420/590]	loss: 0.711228
# Train Epoch: 8 [430/590]	loss: 1.112118
# Train Epoch: 8 [440/590]	loss: 1.161182
# Train Epoch: 8 [450/590]	loss: 1.305169
# Train Epoch: 8 [460/590]	loss: 1.530434
# Train Epoch: 8 [470/590]	loss: 1.323014
# Train Epoch: 8 [480/590]	loss: 0.811124
# Train Epoch: 8 [490/590]	loss: 0.689845
# Train Epoch: 8 [500/590]	loss: 0.685928
# Train Epoch: 8 [510/590]	loss: 0.863909
# Train Epoch: 8 [520/590]	loss: 0.668904
# Train Epoch: 8 [530/590]	loss: 2.297926
# Train Epoch: 8 [540/590]	loss: 0.068474
# Train Epoch: 8 [550/590]	loss: 1.537495
# Train Epoch: 8 [560/590]	loss: 0.655339
# Train Epoch: 8 [570/590]	loss: 0.114722
# Train Epoch: 8 [580/590]	loss: 0.867838
# [8]Validation Loss: 0.9301,Accuracy: 73.9865%
# Train Epoch: 9 [0/590]	loss: 1.641738
# Train Epoch: 9 [10/590]	loss: 0.470486
# Train Epoch: 9 [20/590]	loss: 1.207761
# Train Epoch: 9 [30/590]	loss: 0.431779
# Train Epoch: 9 [40/590]	loss: 0.480235
# Train Epoch: 9 [50/590]	loss: 0.363034
# Train Epoch: 9 [60/590]	loss: 1.188205
# Train Epoch: 9 [70/590]	loss: 0.822036
# Train Epoch: 9 [80/590]	loss: 0.760401
# Train Epoch: 9 [90/590]	loss: 0.582385
# Train Epoch: 9 [100/590]	loss: 1.028588
# Train Epoch: 9 [110/590]	loss: 0.717219
# Train Epoch: 9 [120/590]	loss: 1.210357
# Train Epoch: 9 [130/590]	loss: 0.753047
# Train Epoch: 9 [140/590]	loss: 0.556901
# Train Epoch: 9 [150/590]	loss: 0.546065
# Train Epoch: 9 [160/590]	loss: 1.799421
# Train Epoch: 9 [170/590]	loss: 0.937977
# Train Epoch: 9 [180/590]	loss: 1.239046
# Train Epoch: 9 [190/590]	loss: 1.329702
# Train Epoch: 9 [200/590]	loss: 1.208225
# Train Epoch: 9 [210/590]	loss: 0.805834
# Train Epoch: 9 [220/590]	loss: 1.840110
# Train Epoch: 9 [230/590]	loss: 1.913985
# Train Epoch: 9 [240/590]	loss: 0.587395
# Train Epoch: 9 [250/590]	loss: 0.309732
# Train Epoch: 9 [260/590]	loss: 0.920504
# Train Epoch: 9 [270/590]	loss: 0.560721
# Train Epoch: 9 [280/590]	loss: 0.613092
# Train Epoch: 9 [290/590]	loss: 0.629500
# Train Epoch: 9 [300/590]	loss: 0.514421
# Train Epoch: 9 [310/590]	loss: 0.443185
# Train Epoch: 9 [320/590]	loss: 1.776415
# Train Epoch: 9 [330/590]	loss: 0.437470
# Train Epoch: 9 [340/590]	loss: 0.482801
# Train Epoch: 9 [350/590]	loss: 0.411832
# Train Epoch: 9 [360/590]	loss: 1.130163
# Train Epoch: 9 [370/590]	loss: 0.498653
# Train Epoch: 9 [380/590]	loss: 0.364027
# Train Epoch: 9 [390/590]	loss: 0.294087
# Train Epoch: 9 [400/590]	loss: 0.355038
# Train Epoch: 9 [410/590]	loss: 1.013086
# Train Epoch: 9 [420/590]	loss: 0.211272
# Train Epoch: 9 [430/590]	loss: 0.152182
# Train Epoch: 9 [440/590]	loss: 0.730468
# Train Epoch: 9 [450/590]	loss: 0.608840
# Train Epoch: 9 [460/590]	loss: 0.051772
# Train Epoch: 9 [470/590]	loss: 0.288869
# Train Epoch: 9 [480/590]	loss: 0.479234
# Train Epoch: 9 [490/590]	loss: 1.217360
# Train Epoch: 9 [500/590]	loss: 0.329841
# Train Epoch: 9 [510/590]	loss: 0.218483
# Train Epoch: 9 [520/590]	loss: 0.504809
# Train Epoch: 9 [530/590]	loss: 0.442817
# Train Epoch: 9 [540/590]	loss: 0.021425
# Train Epoch: 9 [550/590]	loss: 1.484753
# Train Epoch: 9 [560/590]	loss: 0.185596
# Train Epoch: 9 [570/590]	loss: 0.810369
# Train Epoch: 9 [580/590]	loss: 0.978465
# [9]Validation Loss: 0.3815,Accuracy: 88.8514%
# Train Epoch: 10 [0/590]	loss: 0.230474
# Train Epoch: 10 [10/590]	loss: 0.016527
# Train Epoch: 10 [20/590]	loss: 0.484033
# Train Epoch: 10 [30/590]	loss: 0.541142
# Train Epoch: 10 [40/590]	loss: 0.279424
# Train Epoch: 10 [50/590]	loss: 0.334057
# Train Epoch: 10 [60/590]	loss: 0.885359
# Train Epoch: 10 [70/590]	loss: 2.044895
# Train Epoch: 10 [80/590]	loss: 0.720893
# Train Epoch: 10 [90/590]	loss: 0.117608
# Train Epoch: 10 [100/590]	loss: 0.663494
# Train Epoch: 10 [110/590]	loss: 0.229800
# Train Epoch: 10 [120/590]	loss: 0.704990
# Train Epoch: 10 [130/590]	loss: 0.774073
# Train Epoch: 10 [140/590]	loss: 0.194390
# Train Epoch: 10 [150/590]	loss: 0.631499
# Train Epoch: 10 [160/590]	loss: 0.068551
# Train Epoch: 10 [170/590]	loss: 0.232170
# Train Epoch: 10 [180/590]	loss: 0.077345
# Train Epoch: 10 [190/590]	loss: 0.167392
# Train Epoch: 10 [200/590]	loss: 0.571225
# Train Epoch: 10 [210/590]	loss: 0.276478
# Train Epoch: 10 [220/590]	loss: 0.509820
# Train Epoch: 10 [230/590]	loss: 0.241492
# Train Epoch: 10 [240/590]	loss: 0.257224
# Train Epoch: 10 [250/590]	loss: 0.491110
# Train Epoch: 10 [260/590]	loss: 0.146697
# Train Epoch: 10 [270/590]	loss: 0.140221
# Train Epoch: 10 [280/590]	loss: 0.105521
# Train Epoch: 10 [290/590]	loss: 0.099606
# Train Epoch: 10 [300/590]	loss: 1.140219
# Train Epoch: 10 [310/590]	loss: 2.980985
# Train Epoch: 10 [320/590]	loss: 1.231649
# Train Epoch: 10 [330/590]	loss: 0.080988
# Train Epoch: 10 [340/590]	loss: 0.655595
# Train Epoch: 10 [350/590]	loss: 0.343588
# Train Epoch: 10 [360/590]	loss: 1.513502
# Train Epoch: 10 [370/590]	loss: 1.047595
# Train Epoch: 10 [380/590]	loss: 0.451934
# Train Epoch: 10 [390/590]	loss: 0.508156
# Train Epoch: 10 [400/590]	loss: 0.792821
# Train Epoch: 10 [410/590]	loss: 0.974253
# Train Epoch: 10 [420/590]	loss: 0.124538
# Train Epoch: 10 [430/590]	loss: 0.808765
# Train Epoch: 10 [440/590]	loss: 0.557885
# Train Epoch: 10 [450/590]	loss: 1.714124
# Train Epoch: 10 [460/590]	loss: 1.679046
# Train Epoch: 10 [470/590]	loss: 0.989421
# Train Epoch: 10 [480/590]	loss: 2.380948
# Train Epoch: 10 [490/590]	loss: 2.351575
# Train Epoch: 10 [500/590]	loss: 1.143843
# Train Epoch: 10 [510/590]	loss: 1.839853
# Train Epoch: 10 [520/590]	loss: 0.574640
# Train Epoch: 10 [530/590]	loss: 1.404506
# Train Epoch: 10 [540/590]	loss: 0.979264
# Train Epoch: 10 [550/590]	loss: 1.478285
# Train Epoch: 10 [560/590]	loss: 1.996850
# Train Epoch: 10 [570/590]	loss: 1.257698
# Train Epoch: 10 [580/590]	loss: 1.304462
# [10]Validation Loss: 1.0008,Accuracy: 71.2838%
# Train Epoch: 11 [0/590]	loss: 0.998147
# Train Epoch: 11 [10/590]	loss: 0.812424
# Train Epoch: 11 [20/590]	loss: 1.112700
# Train Epoch: 11 [30/590]	loss: 0.244519
# Train Epoch: 11 [40/590]	loss: 0.908599
# Train Epoch: 11 [50/590]	loss: 0.928763
# Train Epoch: 11 [60/590]	loss: 0.637993
# Train Epoch: 11 [70/590]	loss: 1.145813
# Train Epoch: 11 [80/590]	loss: 1.451075
# Train Epoch: 11 [90/590]	loss: 1.585011
# Train Epoch: 11 [100/590]	loss: 0.387101
# Train Epoch: 11 [110/590]	loss: 0.672114
# Train Epoch: 11 [120/590]	loss: 1.752834
# Train Epoch: 11 [130/590]	loss: 1.580085
# Train Epoch: 11 [140/590]	loss: 1.575938
# Train Epoch: 11 [150/590]	loss: 0.808943
# Train Epoch: 11 [160/590]	loss: 0.614998
# Train Epoch: 11 [170/590]	loss: 0.459480
# Train Epoch: 11 [180/590]	loss: 1.528179
# Train Epoch: 11 [190/590]	loss: 0.766132
# Train Epoch: 11 [200/590]	loss: 0.734474
# Train Epoch: 11 [210/590]	loss: 0.617264
# Train Epoch: 11 [220/590]	loss: 0.980238
# Train Epoch: 11 [230/590]	loss: 0.918605
# Train Epoch: 11 [240/590]	loss: 1.109284
# Train Epoch: 11 [250/590]	loss: 1.672388
# Train Epoch: 11 [260/590]	loss: 0.465519
# Train Epoch: 11 [270/590]	loss: 0.442579
# Train Epoch: 11 [280/590]	loss: 0.331812
# Train Epoch: 11 [290/590]	loss: 1.663686
# Train Epoch: 11 [300/590]	loss: 1.075341
# Train Epoch: 11 [310/590]	loss: 0.201949
# Train Epoch: 11 [320/590]	loss: 0.673790
# Train Epoch: 11 [330/590]	loss: 0.846054
# Train Epoch: 11 [340/590]	loss: 1.600769
# Train Epoch: 11 [350/590]	loss: 1.294577
# Train Epoch: 11 [360/590]	loss: 0.163795
# Train Epoch: 11 [370/590]	loss: 0.706693
# Train Epoch: 11 [380/590]	loss: 0.075907
# Train Epoch: 11 [390/590]	loss: 0.554126
# Train Epoch: 11 [400/590]	loss: 0.981401
# Train Epoch: 11 [410/590]	loss: 0.477097
# Train Epoch: 11 [420/590]	loss: 0.301167
# Train Epoch: 11 [430/590]	loss: 0.960838
# Train Epoch: 11 [440/590]	loss: 0.135229
# Train Epoch: 11 [450/590]	loss: 0.519639
# Train Epoch: 11 [460/590]	loss: 0.533560
# Train Epoch: 11 [470/590]	loss: 1.166191
# Train Epoch: 11 [480/590]	loss: 0.702434
# Train Epoch: 11 [490/590]	loss: 0.369289
# Train Epoch: 11 [500/590]	loss: 0.504325
# Train Epoch: 11 [510/590]	loss: 0.907096
# Train Epoch: 11 [520/590]	loss: 0.233897
# Train Epoch: 11 [530/590]	loss: 0.111515
# Train Epoch: 11 [540/590]	loss: 0.618729
# Train Epoch: 11 [550/590]	loss: 0.576506
# Train Epoch: 11 [560/590]	loss: 0.268333
# Train Epoch: 11 [570/590]	loss: 0.472097
# Train Epoch: 11 [580/590]	loss: 0.524618
# [11]Validation Loss: 0.3670,Accuracy: 89.1892%
# Train Epoch: 12 [0/590]	loss: 0.167454
# Train Epoch: 12 [10/590]	loss: 0.092313
# Train Epoch: 12 [20/590]	loss: 0.165940
# Train Epoch: 12 [30/590]	loss: 0.836080
# Train Epoch: 12 [40/590]	loss: 0.242533
# Train Epoch: 12 [50/590]	loss: 0.660509
# Train Epoch: 12 [60/590]	loss: 0.208270
# Train Epoch: 12 [70/590]	loss: 0.094126
# Train Epoch: 12 [80/590]	loss: 0.441629
# Train Epoch: 12 [90/590]	loss: 0.088681
# Train Epoch: 12 [100/590]	loss: 1.726393
# Train Epoch: 12 [110/590]	loss: 0.403688
# Train Epoch: 12 [120/590]	loss: 0.029781
# Train Epoch: 12 [130/590]	loss: 0.350920
# Train Epoch: 12 [140/590]	loss: 0.226515
# Train Epoch: 12 [150/590]	loss: 1.043411
# Train Epoch: 12 [160/590]	loss: 0.946566
# Train Epoch: 12 [170/590]	loss: 0.063052
# Train Epoch: 12 [180/590]	loss: 0.283326
# Train Epoch: 12 [190/590]	loss: 0.407705
# Train Epoch: 12 [200/590]	loss: 0.588173
# Train Epoch: 12 [210/590]	loss: 0.201238
# Train Epoch: 12 [220/590]	loss: 0.118180
# Train Epoch: 12 [230/590]	loss: 0.098756
# Train Epoch: 12 [240/590]	loss: 0.845430
# Train Epoch: 12 [250/590]	loss: 0.202682
# Train Epoch: 12 [260/590]	loss: 0.630693
# Train Epoch: 12 [270/590]	loss: 0.576720
# Train Epoch: 12 [280/590]	loss: 0.045091
# Train Epoch: 12 [290/590]	loss: 0.150151
# Train Epoch: 12 [300/590]	loss: 0.307481
# Train Epoch: 12 [310/590]	loss: 0.704979
# Train Epoch: 12 [320/590]	loss: 0.175532
# Train Epoch: 12 [330/590]	loss: 0.308210
# Train Epoch: 12 [340/590]	loss: 1.022971
# Train Epoch: 12 [350/590]	loss: 0.579341
# Train Epoch: 12 [360/590]	loss: 0.556115
# Train Epoch: 12 [370/590]	loss: 0.787166
# Train Epoch: 12 [380/590]	loss: 0.275404
# Train Epoch: 12 [390/590]	loss: 0.451736
# Train Epoch: 12 [400/590]	loss: 1.452635
# Train Epoch: 12 [410/590]	loss: 0.652703
# Train Epoch: 12 [420/590]	loss: 0.963740
# Train Epoch: 12 [430/590]	loss: 0.478175
# Train Epoch: 12 [440/590]	loss: 0.868432
# Train Epoch: 12 [450/590]	loss: 0.302603
# Train Epoch: 12 [460/590]	loss: 1.049747
# Train Epoch: 12 [470/590]	loss: 0.523586
# Train Epoch: 12 [480/590]	loss: 0.710550
# Train Epoch: 12 [490/590]	loss: 1.457002
# Train Epoch: 12 [500/590]	loss: 0.847615
# Train Epoch: 12 [510/590]	loss: 0.935069
# Train Epoch: 12 [520/590]	loss: 2.029156
# Train Epoch: 12 [530/590]	loss: 0.832954
# Train Epoch: 12 [540/590]	loss: 0.333377
# Train Epoch: 12 [550/590]	loss: 1.855705
# Train Epoch: 12 [560/590]	loss: 0.508443
# Train Epoch: 12 [570/590]	loss: 1.425767
# Train Epoch: 12 [580/590]	loss: 0.562000
# [12]Validation Loss: 1.0117,Accuracy: 70.6081%
# Train Epoch: 13 [0/590]	loss: 0.740572
# Train Epoch: 13 [10/590]	loss: 1.301983
# Train Epoch: 13 [20/590]	loss: 1.673236
# Train Epoch: 13 [30/590]	loss: 1.286720
# Train Epoch: 13 [40/590]	loss: 0.920573
# Train Epoch: 13 [50/590]	loss: 0.558927
# Train Epoch: 13 [60/590]	loss: 1.430168
# Train Epoch: 13 [70/590]	loss: 1.986482
# Train Epoch: 13 [80/590]	loss: 0.809795
# Train Epoch: 13 [90/590]	loss: 0.577021
# Train Epoch: 13 [100/590]	loss: 0.967617
# Train Epoch: 13 [110/590]	loss: 2.203179
# Train Epoch: 13 [120/590]	loss: 0.171583
# Train Epoch: 13 [130/590]	loss: 0.405194
# Train Epoch: 13 [140/590]	loss: 0.848103
# Train Epoch: 13 [150/590]	loss: 0.498863
# Train Epoch: 13 [160/590]	loss: 0.687152
# Train Epoch: 13 [170/590]	loss: 1.295301
# Train Epoch: 13 [180/590]	loss: 0.500374
# Train Epoch: 13 [190/590]	loss: 0.474937
# Train Epoch: 13 [200/590]	loss: 1.253077
# Train Epoch: 13 [210/590]	loss: 0.251444
# Train Epoch: 13 [220/590]	loss: 0.872445
# Train Epoch: 13 [230/590]	loss: 0.761422
# Train Epoch: 13 [240/590]	loss: 0.386038
# Train Epoch: 13 [250/590]	loss: 0.081256
# Train Epoch: 13 [260/590]	loss: 0.262245
# Train Epoch: 13 [270/590]	loss: 1.508465
# Train Epoch: 13 [280/590]	loss: 1.845946
# Train Epoch: 13 [290/590]	loss: 0.369329
# Train Epoch: 13 [300/590]	loss: 0.342117
# Train Epoch: 13 [310/590]	loss: 0.581978
# Train Epoch: 13 [320/590]	loss: 0.768038
# Train Epoch: 13 [330/590]	loss: 0.582606
# Train Epoch: 13 [340/590]	loss: 0.438444
# Train Epoch: 13 [350/590]	loss: 1.075371
# Train Epoch: 13 [360/590]	loss: 0.884818
# Train Epoch: 13 [370/590]	loss: 0.391728
# Train Epoch: 13 [380/590]	loss: 0.098719
# Train Epoch: 13 [390/590]	loss: 1.571584
# Train Epoch: 13 [400/590]	loss: 0.828016
# Train Epoch: 13 [410/590]	loss: 0.407182
# Train Epoch: 13 [420/590]	loss: 0.325369
# Train Epoch: 13 [430/590]	loss: 0.234441
# Train Epoch: 13 [440/590]	loss: 0.677980
# Train Epoch: 13 [450/590]	loss: 0.575364
# Train Epoch: 13 [460/590]	loss: 0.029656
# Train Epoch: 13 [470/590]	loss: 1.109875
# Train Epoch: 13 [480/590]	loss: 0.690887
# Train Epoch: 13 [490/590]	loss: 0.120950
# Train Epoch: 13 [500/590]	loss: 1.166829
# Train Epoch: 13 [510/590]	loss: 0.090220
# Train Epoch: 13 [520/590]	loss: 0.374200
# Train Epoch: 13 [530/590]	loss: 1.838760
# Train Epoch: 13 [540/590]	loss: 1.047639
# Train Epoch: 13 [550/590]	loss: 0.969461
# Train Epoch: 13 [560/590]	loss: 0.570658
# Train Epoch: 13 [570/590]	loss: 0.572866
# Train Epoch: 13 [580/590]	loss: 0.520166
# [13]Validation Loss: 0.3810,Accuracy: 89.5270%
# Train Epoch: 14 [0/590]	loss: 0.482094
# Train Epoch: 14 [10/590]	loss: 0.113047
# Train Epoch: 14 [20/590]	loss: 0.250618
# Train Epoch: 14 [30/590]	loss: 0.125155
# Train Epoch: 14 [40/590]	loss: 0.870067
# Train Epoch: 14 [50/590]	loss: 0.031713
# Train Epoch: 14 [60/590]	loss: 0.638882
# Train Epoch: 14 [70/590]	loss: 0.761437
# Train Epoch: 14 [80/590]	loss: 1.000411
# Train Epoch: 14 [90/590]	loss: 1.223439
# Train Epoch: 14 [100/590]	loss: 0.936705
# Train Epoch: 14 [110/590]	loss: 0.502609
# Train Epoch: 14 [120/590]	loss: 0.330183
# Train Epoch: 14 [130/590]	loss: 0.061700
# Train Epoch: 14 [140/590]	loss: 0.035222
# Train Epoch: 14 [150/590]	loss: 0.260819
# Train Epoch: 14 [160/590]	loss: 0.168986
# Train Epoch: 14 [170/590]	loss: 0.591197
# Train Epoch: 14 [180/590]	loss: 0.294780
# Train Epoch: 14 [190/590]	loss: 0.079920
# Train Epoch: 14 [200/590]	loss: 0.108476
# Train Epoch: 14 [210/590]	loss: 0.790948
# Train Epoch: 14 [220/590]	loss: 0.423730
# Train Epoch: 14 [230/590]	loss: 0.272043
# Train Epoch: 14 [240/590]	loss: 0.235205
# Train Epoch: 14 [250/590]	loss: 0.369024
# Train Epoch: 14 [260/590]	loss: 1.054486
# Train Epoch: 14 [270/590]	loss: 0.734025
# Train Epoch: 14 [280/590]	loss: 0.523135
# Train Epoch: 14 [290/590]	loss: 0.287307
# Train Epoch: 14 [300/590]	loss: 0.212710
# Train Epoch: 14 [310/590]	loss: 0.179784
# Train Epoch: 14 [320/590]	loss: 0.072324
# Train Epoch: 14 [330/590]	loss: 1.075813
# Train Epoch: 14 [340/590]	loss: 1.167811
# Train Epoch: 14 [350/590]	loss: 0.738553
# Train Epoch: 14 [360/590]	loss: 0.095654
# Train Epoch: 14 [370/590]	loss: 0.505542
# Train Epoch: 14 [380/590]	loss: 0.182485
# Train Epoch: 14 [390/590]	loss: 0.027723
# Train Epoch: 14 [400/590]	loss: 0.799549
# Train Epoch: 14 [410/590]	loss: 1.377632
# Train Epoch: 14 [420/590]	loss: 0.439058
# Train Epoch: 14 [430/590]	loss: 0.931389
# Train Epoch: 14 [440/590]	loss: 1.226078
# Train Epoch: 14 [450/590]	loss: 0.511340
# Train Epoch: 14 [460/590]	loss: 0.471644
# Train Epoch: 14 [470/590]	loss: 0.878273
# Train Epoch: 14 [480/590]	loss: 0.650607
# Train Epoch: 14 [490/590]	loss: 0.181588
# Train Epoch: 14 [500/590]	loss: 1.441649
# Train Epoch: 14 [510/590]	loss: 0.204222
# Train Epoch: 14 [520/590]	loss: 0.660089
# Train Epoch: 14 [530/590]	loss: 2.071931
# Train Epoch: 14 [540/590]	loss: 1.786457
# Train Epoch: 14 [550/590]	loss: 1.782899
# Train Epoch: 14 [560/590]	loss: 2.236817
# Train Epoch: 14 [570/590]	loss: 1.505986
# Train Epoch: 14 [580/590]	loss: 0.528442
# [14]Validation Loss: 0.7246,Accuracy: 79.0541%
# Train Epoch: 15 [0/590]	loss: 2.068569
# Train Epoch: 15 [10/590]	loss: 1.070714
# Train Epoch: 15 [20/590]	loss: 2.106977
# Train Epoch: 15 [30/590]	loss: 1.019052
# Train Epoch: 15 [40/590]	loss: 1.323055
# Train Epoch: 15 [50/590]	loss: 0.728613
# Train Epoch: 15 [60/590]	loss: 1.078337
# Train Epoch: 15 [70/590]	loss: 0.615189
# Train Epoch: 15 [80/590]	loss: 0.447822
# Train Epoch: 15 [90/590]	loss: 0.427685
# Train Epoch: 15 [100/590]	loss: 0.813696
# Train Epoch: 15 [110/590]	loss: 1.366085
# Train Epoch: 15 [120/590]	loss: 1.925835
# Train Epoch: 15 [130/590]	loss: 1.117662
# Train Epoch: 15 [140/590]	loss: 1.170318
# Train Epoch: 15 [150/590]	loss: 0.590934
# Train Epoch: 15 [160/590]	loss: 1.183738
# Train Epoch: 15 [170/590]	loss: 1.844025
# Train Epoch: 15 [180/590]	loss: 1.860613
# Train Epoch: 15 [190/590]	loss: 1.897289
# Train Epoch: 15 [200/590]	loss: 1.367043
# Train Epoch: 15 [210/590]	loss: 1.532999
# Train Epoch: 15 [220/590]	loss: 0.691094
# Train Epoch: 15 [230/590]	loss: 1.364331
# Train Epoch: 15 [240/590]	loss: 1.201690
# Train Epoch: 15 [250/590]	loss: 0.973851
# Train Epoch: 15 [260/590]	loss: 0.427671
# Train Epoch: 15 [270/590]	loss: 0.272893
# Train Epoch: 15 [280/590]	loss: 0.907664
# Train Epoch: 15 [290/590]	loss: 0.839221
# Train Epoch: 15 [300/590]	loss: 0.899133
# Train Epoch: 15 [310/590]	loss: 1.144618
# Train Epoch: 15 [320/590]	loss: 1.600145
# Train Epoch: 15 [330/590]	loss: 0.118337
# Train Epoch: 15 [340/590]	loss: 0.686929
# Train Epoch: 15 [350/590]	loss: 0.547011
# Train Epoch: 15 [360/590]	loss: 0.240968
# Train Epoch: 15 [370/590]	loss: 1.056821
# Train Epoch: 15 [380/590]	loss: 0.748947
# Train Epoch: 15 [390/590]	loss: 0.348250
# Train Epoch: 15 [400/590]	loss: 0.381248
# Train Epoch: 15 [410/590]	loss: 0.369077
# Train Epoch: 15 [420/590]	loss: 1.778775
# Train Epoch: 15 [430/590]	loss: 0.755131
# Train Epoch: 15 [440/590]	loss: 0.258305
# Train Epoch: 15 [450/590]	loss: 0.829380
# Train Epoch: 15 [460/590]	loss: 0.706487
# Train Epoch: 15 [470/590]	loss: 0.827326
# Train Epoch: 15 [480/590]	loss: 0.322709
# Train Epoch: 15 [490/590]	loss: 0.446944
# Train Epoch: 15 [500/590]	loss: 1.527806
# Train Epoch: 15 [510/590]	loss: 1.283334
# Train Epoch: 15 [520/590]	loss: 1.126219
# Train Epoch: 15 [530/590]	loss: 0.860393
# Train Epoch: 15 [540/590]	loss: 0.814367
# Train Epoch: 15 [550/590]	loss: 0.782314
# Train Epoch: 15 [560/590]	loss: 0.279156
# Train Epoch: 15 [570/590]	loss: 0.163380
# Train Epoch: 15 [580/590]	loss: 0.584689
# [15]Validation Loss: 0.3455,Accuracy: 90.5405%
# Train Epoch: 16 [0/590]	loss: 0.039917
# Train Epoch: 16 [10/590]	loss: 0.375437
# Train Epoch: 16 [20/590]	loss: 0.228907
# Train Epoch: 16 [30/590]	loss: 0.183128
# Train Epoch: 16 [40/590]	loss: 0.353134
# Train Epoch: 16 [50/590]	loss: 1.647959
# Train Epoch: 16 [60/590]	loss: 0.313768
# Train Epoch: 16 [70/590]	loss: 1.039505
# Train Epoch: 16 [80/590]	loss: 0.654210
# Train Epoch: 16 [90/590]	loss: 0.516854
# Train Epoch: 16 [100/590]	loss: 1.505594
# Train Epoch: 16 [110/590]	loss: 0.262726
# Train Epoch: 16 [120/590]	loss: 1.582879
# Train Epoch: 16 [130/590]	loss: 0.520576
# Train Epoch: 16 [140/590]	loss: 0.445059
# Train Epoch: 16 [150/590]	loss: 0.137344
# Train Epoch: 16 [160/590]	loss: 0.726211
# Train Epoch: 16 [170/590]	loss: 0.842931
# Train Epoch: 16 [180/590]	loss: 0.548184
# Train Epoch: 16 [190/590]	loss: 0.258330
# Train Epoch: 16 [200/590]	loss: 0.762900
# Train Epoch: 16 [210/590]	loss: 0.031741
# Train Epoch: 16 [220/590]	loss: 0.370913
# Train Epoch: 16 [230/590]	loss: 0.337965
# Train Epoch: 16 [240/590]	loss: 0.075720
# Train Epoch: 16 [250/590]	loss: 1.186787
# Train Epoch: 16 [260/590]	loss: 0.817815
# Train Epoch: 16 [270/590]	loss: 0.588594
# Train Epoch: 16 [280/590]	loss: 0.175551
# Train Epoch: 16 [290/590]	loss: 0.225675
# Train Epoch: 16 [300/590]	loss: 1.337624
# Train Epoch: 16 [310/590]	loss: 0.122305
# Train Epoch: 16 [320/590]	loss: 0.642390
# Train Epoch: 16 [330/590]	loss: 0.088779
# Train Epoch: 16 [340/590]	loss: 0.356734
# Train Epoch: 16 [350/590]	loss: 0.522009
# Train Epoch: 16 [360/590]	loss: 0.308699
# Train Epoch: 16 [370/590]	loss: 0.382378
# Train Epoch: 16 [380/590]	loss: 0.460705
# Train Epoch: 16 [390/590]	loss: 0.641777
# Train Epoch: 16 [400/590]	loss: 0.250355
# Train Epoch: 16 [410/590]	loss: 0.895468
# Train Epoch: 16 [420/590]	loss: 0.619309
# Train Epoch: 16 [430/590]	loss: 0.520618
# Train Epoch: 16 [440/590]	loss: 0.643212
# Train Epoch: 16 [450/590]	loss: 1.222699
# Train Epoch: 16 [460/590]	loss: 0.118975
# Train Epoch: 16 [470/590]	loss: 1.267279
# Train Epoch: 16 [480/590]	loss: 0.748135
# Train Epoch: 16 [490/590]	loss: 0.817483
# Train Epoch: 16 [500/590]	loss: 1.776050
# Train Epoch: 16 [510/590]	loss: 0.371485
# Train Epoch: 16 [520/590]	loss: 1.008503
# Train Epoch: 16 [530/590]	loss: 0.250800
# Train Epoch: 16 [540/590]	loss: 1.300489
# Train Epoch: 16 [550/590]	loss: 0.483925
# Train Epoch: 16 [560/590]	loss: 0.967482
# Train Epoch: 16 [570/590]	loss: 1.471963
# Train Epoch: 16 [580/590]	loss: 1.216184
# [16]Validation Loss: 0.9369,Accuracy: 72.6351%
# Train Epoch: 17 [0/590]	loss: 0.814871
# Train Epoch: 17 [10/590]	loss: 0.763547
# Train Epoch: 17 [20/590]	loss: 0.728590
# Train Epoch: 17 [30/590]	loss: 0.473184
# Train Epoch: 17 [40/590]	loss: 0.960380
# Train Epoch: 17 [50/590]	loss: 1.178265
# Train Epoch: 17 [60/590]	loss: 0.840953
# Train Epoch: 17 [70/590]	loss: 1.225848
# Train Epoch: 17 [80/590]	loss: 0.107212
# Train Epoch: 17 [90/590]	loss: 0.621846
# Train Epoch: 17 [100/590]	loss: 1.536691
# Train Epoch: 17 [110/590]	loss: 2.022828
# Train Epoch: 17 [120/590]	loss: 0.408990
# Train Epoch: 17 [130/590]	loss: 0.627165
# Train Epoch: 17 [140/590]	loss: 1.780640
# Train Epoch: 17 [150/590]	loss: 1.038821
# Train Epoch: 17 [160/590]	loss: 1.494790
# Train Epoch: 17 [170/590]	loss: 1.231735
# Train Epoch: 17 [180/590]	loss: 0.218336
# Train Epoch: 17 [190/590]	loss: 1.319605
# Train Epoch: 17 [200/590]	loss: 0.455371
# Train Epoch: 17 [210/590]	loss: 0.738463
# Train Epoch: 17 [220/590]	loss: 0.331787
# Train Epoch: 17 [230/590]	loss: 0.619205
# Train Epoch: 17 [240/590]	loss: 0.619273
# Train Epoch: 17 [250/590]	loss: 0.105389
# Train Epoch: 17 [260/590]	loss: 0.753920
# Train Epoch: 17 [270/590]	loss: 0.031831
# Train Epoch: 17 [280/590]	loss: 0.360818
# Train Epoch: 17 [290/590]	loss: 0.496208
# Train Epoch: 17 [300/590]	loss: 0.296399
# Train Epoch: 17 [310/590]	loss: 0.748469
# Train Epoch: 17 [320/590]	loss: 0.779310
# Train Epoch: 17 [330/590]	loss: 0.370462
# Train Epoch: 17 [340/590]	loss: 0.935024
# Train Epoch: 17 [350/590]	loss: 1.813211
# Train Epoch: 17 [360/590]	loss: 0.803350
# Train Epoch: 17 [370/590]	loss: 0.543929
# Train Epoch: 17 [380/590]	loss: 0.346536
# Train Epoch: 17 [390/590]	loss: 1.043252
# Train Epoch: 17 [400/590]	loss: 0.520993
# Train Epoch: 17 [410/590]	loss: 0.551603
# Train Epoch: 17 [420/590]	loss: 0.027869
# Train Epoch: 17 [430/590]	loss: 0.760534
# Train Epoch: 17 [440/590]	loss: 0.727400
# Train Epoch: 17 [450/590]	loss: 0.401910
# Train Epoch: 17 [460/590]	loss: 0.819904
# Train Epoch: 17 [470/590]	loss: 0.037061
# Train Epoch: 17 [480/590]	loss: 0.459294
# Train Epoch: 17 [490/590]	loss: 0.166022
# Train Epoch: 17 [500/590]	loss: 0.813179
# Train Epoch: 17 [510/590]	loss: 0.148755
# Train Epoch: 17 [520/590]	loss: 0.232821
# Train Epoch: 17 [530/590]	loss: 0.122272
# Train Epoch: 17 [540/590]	loss: 0.094025
# Train Epoch: 17 [550/590]	loss: 0.431427
# Train Epoch: 17 [560/590]	loss: 0.277711
# Train Epoch: 17 [570/590]	loss: 0.227397
# Train Epoch: 17 [580/590]	loss: 0.560809
# [17]Validation Loss: 0.3764,Accuracy: 88.1757%
# Train Epoch: 18 [0/590]	loss: 0.485718
# Train Epoch: 18 [10/590]	loss: 0.588358
# Train Epoch: 18 [20/590]	loss: 0.651505
# Train Epoch: 18 [30/590]	loss: 0.058186
# Train Epoch: 18 [40/590]	loss: 1.268559
# Train Epoch: 18 [50/590]	loss: 0.716291
# Train Epoch: 18 [60/590]	loss: 0.339581
# Train Epoch: 18 [70/590]	loss: 0.291153
# Train Epoch: 18 [80/590]	loss: 0.169040
# Train Epoch: 18 [90/590]	loss: 0.228064
# Train Epoch: 18 [100/590]	loss: 0.985600
# Train Epoch: 18 [110/590]	loss: 0.514234
# Train Epoch: 18 [120/590]	loss: 0.149604
# Train Epoch: 18 [130/590]	loss: 0.109759
# Train Epoch: 18 [140/590]	loss: 0.481298
# Train Epoch: 18 [150/590]	loss: 0.442850
# Train Epoch: 18 [160/590]	loss: 0.810205
# Train Epoch: 18 [170/590]	loss: 0.610274
# Train Epoch: 18 [180/590]	loss: 0.223195
# Train Epoch: 18 [190/590]	loss: 0.109320
# Train Epoch: 18 [200/590]	loss: 0.104515
# Train Epoch: 18 [210/590]	loss: 0.174038
# Train Epoch: 18 [220/590]	loss: 0.696987
# Train Epoch: 18 [230/590]	loss: 1.741677
# Train Epoch: 18 [240/590]	loss: 0.436697
# Train Epoch: 18 [250/590]	loss: 1.158033
# Train Epoch: 18 [260/590]	loss: 0.543308
# Train Epoch: 18 [270/590]	loss: 0.365547
# Train Epoch: 18 [280/590]	loss: 0.435655
# Train Epoch: 18 [290/590]	loss: 0.428842
# Train Epoch: 18 [300/590]	loss: 0.308380
# Train Epoch: 18 [310/590]	loss: 0.367147
# Train Epoch: 18 [320/590]	loss: 1.857274
# Train Epoch: 18 [330/590]	loss: 0.266670
# Train Epoch: 18 [340/590]	loss: 0.315073
# Train Epoch: 18 [350/590]	loss: 0.478712
# Train Epoch: 18 [360/590]	loss: 1.129019
# Train Epoch: 18 [370/590]	loss: 0.502822
# Train Epoch: 18 [380/590]	loss: 0.625950
# Train Epoch: 18 [390/590]	loss: 0.286431
# Train Epoch: 18 [400/590]	loss: 0.077703
# Train Epoch: 18 [410/590]	loss: 1.141230
# Train Epoch: 18 [420/590]	loss: 0.240384
# Train Epoch: 18 [430/590]	loss: 2.470366
# Train Epoch: 18 [440/590]	loss: 0.348662
# Train Epoch: 18 [450/590]	loss: 1.221565
# Train Epoch: 18 [460/590]	loss: 1.105153
# Train Epoch: 18 [470/590]	loss: 0.412101
# Train Epoch: 18 [480/590]	loss: 0.222311
# Train Epoch: 18 [490/590]	loss: 0.499510
# Train Epoch: 18 [500/590]	loss: 1.668819
# Train Epoch: 18 [510/590]	loss: 0.641423
# Train Epoch: 18 [520/590]	loss: 0.504678
# Train Epoch: 18 [530/590]	loss: 1.795955
# Train Epoch: 18 [540/590]	loss: 0.966469
# Train Epoch: 18 [550/590]	loss: 1.518499
# Train Epoch: 18 [560/590]	loss: 1.148511
# Train Epoch: 18 [570/590]	loss: 0.340005
# Train Epoch: 18 [580/590]	loss: 0.859698
# [18]Validation Loss: 0.9233,Accuracy: 76.0135%
# Train Epoch: 19 [0/590]	loss: 0.954632
# Train Epoch: 19 [10/590]	loss: 1.102331
# Train Epoch: 19 [20/590]	loss: 0.921002
# Train Epoch: 19 [30/590]	loss: 0.829813
# Train Epoch: 19 [40/590]	loss: 1.252837
# Train Epoch: 19 [50/590]	loss: 1.092939
# Train Epoch: 19 [60/590]	loss: 2.257371
# Train Epoch: 19 [70/590]	loss: 1.802359
# Train Epoch: 19 [80/590]	loss: 2.034447
# Train Epoch: 19 [90/590]	loss: 1.626548
# Train Epoch: 19 [100/590]	loss: 0.826466
# Train Epoch: 19 [110/590]	loss: 0.512675
# Train Epoch: 19 [120/590]	loss: 0.776290
# Train Epoch: 19 [130/590]	loss: 0.829468
# Train Epoch: 19 [140/590]	loss: 1.040963
# Train Epoch: 19 [150/590]	loss: 0.954422
# Train Epoch: 19 [160/590]	loss: 0.383800
# Train Epoch: 19 [170/590]	loss: 1.146248
# Train Epoch: 19 [180/590]	loss: 0.371472
# Train Epoch: 19 [190/590]	loss: 1.054115
# Train Epoch: 19 [200/590]	loss: 1.802887
# Train Epoch: 19 [210/590]	loss: 1.015796
# Train Epoch: 19 [220/590]	loss: 0.588036
# Train Epoch: 19 [230/590]	loss: 0.509729
# Train Epoch: 19 [240/590]	loss: 0.510564

# %%
# Plot the loss values
import matplotlib.pyplot as plt

# Move train_loss and val_loss tensors to CPU and convert them to NumPy arrays
train_losses = [loss.cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in train_losses]
val_losses = [loss.
              cpu().detach().numpy() if isinstance(loss, torch.Tensor) else loss for loss in val_losses]

plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), train_losses, label='train_loss', marker='o')
plt.plot(range(1, EPOCH + 1), val_losses, label='val_loss', marker='o')
plt.title('Training and Validation Loss Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()


val_accuracys = [acc.cpu().detach().numpy() if isinstance(acc, torch.Tensor) else acc for acc in val_accuracys]
plt.figure(figsize=(12, 6))
plt.plot(range(1, EPOCH + 1), val_accuracys, label='val_accuracy', marker='o')
plt.title('Validation Accuracy Over Epochs')

plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# !pip install git+https://github.com/jacobgil/pytorch-grad-cam.git

# import copy
# from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
# from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
# from pytorch_grad_cam.utils.image import show_cam_on_image

# import numpy as np
# from PIL import Image

# import torchvision
# #
# # Pick up layers for visualization
# target_layers = [model.layer4[-1]]
# grad_cam = GradCam(model = model, target_layers, use_cuda=False)

# # You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
# grayscale_cam = cam(input_tensor=input_tensor)

# # In this example grayscale_cam has only one image in the batch:
# grayscale_cam = grayscale_cam[0, :]
# visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

# %%
# # gradCAM
# import cv2
# from google.colab.patches import cv2_imshow                                      # cv2.imshow() should be replaced to cv2_imshow() in google.colab
# import glob
# import numpy as np


# class GradCam(nn.Module):
#     def __init__(self, model, module, layer):
#         super().__init__()
#         self.model = model
#         self.module = module
#         self.layer = layer
#         self.register_hooks()

#     def register_hooks(self):
#         for modue_name, module in self.model._modules.items():
#             if modue_name == self.module:
#                 for layer_name, module in module._modules.items():
#                     if layer_name == self.layer:
#                         module.register_forward_hook(self.forward_hook)
#                         module.register_backward_hook(self.backward_hook)

#     def forward(self, input, target_index):
#         outs = self.model(input)
#         outs = outs.squeeze()                                                    # [1, num_classes]  --> [num_classes]
#         outs = outs.to(DEVICE)

#         # 가장 큰 값을 가지는 것을 target index 로 사용
#         if target_index is None:
#             target_index = outs.argmax()
#             target_index = target_index.to(DEVICE)

#         outs[target_index].backward(retain_graph=True)
#         a_k = torch.mean(self.backward_result, dim=(1, 2), keepdim=True)         # [512, 1, 1]
#         out = torch.sum(a_k * self.forward_result, dim=0).cuda()                 # [512, 7, 7] * [512, 1, 1]
#         out = torch.relu(out) / torch.max(out)                                   # 음수를 없애고, 0 ~ 1 로 scaling # [7, 7]
#         out = F.upsample_bilinear(out.unsqueeze(0).unsqueeze(0), [224, 224])     # 4D로 바꿈
#         return out.cuda().detach().squeeze().numpy()

#     def forward_hook(self, _, input, output):
#         self.forward_result = torch.squeeze(output)

#     def backward_hook(self, _, grad_input, grad_output):
#         self.backward_result = torch.squeeze(grad_output[0])


# if __name__ == '__main__':

#     def preprocess_image(img):
#         means = [0.485, 0.456, 0.406]
#         stds = [0.229, 0.224, 0.225]

#         preprocessed_img = img.copy()[:, :, ::-1]
#         for i in range(3):
#             preprocessed_img[:, :, i] = preprocessed_img[:, :, i] - means[i]
#             preprocessed_img[:, :, i] = preprocessed_img[:, :, i] / stds[i]
#         preprocessed_img = np.ascontiguousarray(np.transpose(preprocessed_img, (2, 0, 1)))
#         preprocessed_img = torch.from_numpy(preprocessed_img)
#         preprocessed_img.unsqueeze_(0)
#         input = preprocessed_img.requires_grad_(True)
#         return input


#     def show_cam_on_image(img, mask):

#         # mask = (np.max(mask) - np.min(mask)) / (mask - np.min(mask))
#         heatmap = cv2.applyColorMap(np.uint8(255 * mask), cv2.COLORMAP_JET)
#         heatmap = np.float32(heatmap) / 255
#         cam = heatmap + np.float32(img)
#         cam = cam / np.max(cam)
#         cv2_imshow(np.uint8(255 * cam))                                          # cv2_imshow()에서 두 개의 parameter 사용 불가 --> print 부분과 imshow 부분으로 분리
#         print("cam")
#         cv2_imshow(np.uint8(heatmap * 255))
#         print("heat map\n\n\n")
#         cv2.waitKey()



#     print(model)
#     #model.eval()

#     grad_cam = GradCam(model=model, module='features', layer='30')
#     root = '/content/gdrive/MyDrive/CUB_200_2011_repackage_class50/datasets/test'
#     img_list = os.listdir(root)
#     img_list = sorted(glob.glob(os.path.join(root, '*.jpg')))
#     i = 0                                                                        # just for numbering heat maps
#     for img_path in img_list:
#         img = cv2.imread(img_path, 1)
#         #img = np.float32(cv2.resize(img, (224, 224))) / 255
#         img = np.float32(cv2.resize(img, (448, 448))) / 255
#         input = preprocess_image(img)
#         input = input.to(DEVICE)                                                 # input datas should be on GPU
#         mask = grad_cam(input, None)
#         print("<{}'th image>" .format(i))
#         show_cam_on_image(img, mask)
#         i = i + 1                                                                # update heat maps numbering

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# Display
from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

model_builder = keras.applications.xception.Xception
img_size = (299, 299)
preprocess_input = keras.applications.xception.preprocess_input
decode_predictions = keras.applications.xception.decode_predictions

last_conv_layer_name = "block14_sepconv2_act"

# The local path to our target image
import random

# 테스트 데이터셋에서 무작위로 이미지 선택
random_index = random.randint(0, len(test_set) - 1)
img_path = test_set.image_folder[random_index]
img_path = os.path.join('/content/drive/MyDrive/datasets/test', img_path)
display(Image(img_path))

def get_img_array(img_path, size):
    # `img` is a PIL image of size 299x299
    img = keras.utils.load_img(img_path, target_size=size)
    # `array` is a float32 Numpy array of shape (299, 299, 3)
    array = keras.utils.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = keras.models.Model(
        model.inputs, [model.get_layer(last_conv_layer_name).output, model.output]
    )

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
# Prepare image
img_array = preprocess_input(get_img_array(img_path, size=img_size))

# Make model
model = model_builder(weights="imagenet")

# Remove last layer's softmax
model.layers[-1].activation = None

# Print what the top predicted class is
preds = model.predict(img_array)
print("Predicted:", decode_predictions(preds, top=1)[0])

# Generate class activation heatmap
heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)

# Display heatmap
plt.matshow(heatmap)
plt.show()

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = keras.utils.load_img(img_path)
    img = keras.utils.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = keras.utils.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.utils.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.utils.array_to_img(superimposed_img)

    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
    display(Image(cam_path))


save_and_display_gradcam(img_path, heatmap)

# %%
# #keras안쓰고 토치기반으로 하는 중인데 잘 안되구 오류나서 고치는 중입니다

# class GradCAM:
#     def __init__(self, model, target_layer):
#         self.model = model
#         self.target_layer = target_layer
#         self.gradients = None
#         self.activations = None

#     def save_gradient(self, grad):
#         self.gradients = grad
# #
#     def save_activation(self, module, input, output):
#         self.activations = output

#     def forward(self, x):
#         return self.model(x)

#     def backward(self, output, class_idx):
#         self.model.zero_grad()
#         one_hot_output = torch.FloatTensor(1, output.size()[-1]).zero_().to(DEVICE)
#         one_hot_output[0][class_idx] = 1
#         one_hot_output = one_hot_output.to(DEVICE)

#         self.save_gradient(one_hot_output)
#         output.backward(gradient=one_hot_output, retain_graph=True)

#     def generate(self, input_image, class_idx):
#         self.model.eval()
#         hook = self.target_layer.register_forward_hook(self.save_activation)
#         output = self.forward(input_image)
#         hook.remove()

#         self.backward(output, class_idx)

#         gradients = self.gradients.cpu().data.numpy()[0]
#         activations = self.activations.cpu().data.numpy()[0]

#         weights = np.mean(gradients, axis=(1, 2))
#         cam = np.dot(activations.T, weights)
#         cam = np.maximum(0, cam)
#         cam = cv2.resize(cam, input_image.shape[2:])
#         cam = cam - np.min(cam)
#         cam = cam / np.max(cam)
#         return cam

# # Now, modify your apply_gradcam function as follows:

# def apply_gradcam(image_path, model, target_layer, classes):
#     model.eval()
#     image = Image.open(image_path).convert('RGB')
#     image_tensor = transforms_valtest(image).unsqueeze(0).to(DEVICE)
#     class_idx = model(image_tensor).max(1)[-1]

#     gradcam = GradCAM(model=model, target_layer=target_layer)
#     output = gradcam.generate(image_tensor, class_idx)

#     heatmap = cv2.applyColorMap(np.uint8(255 * output), cv2.COLORMAP_JET)
#     heatmap = np.float32(heatmap) / 255
#     cam_img = heatmap + np.float32(image_tensor.cpu().squeeze().permute(1, 2, 0))
#     cam_img = cam_img / np.max(cam_img)

#     original_image = Image.open(image_path).convert('RGB')
#     original_image = transforms_valtest(original_image).numpy().transpose(1, 2, 0)

#     plt.imshow(cam_img)
#     plt.title(f'Predicted Class: {classes[class_idx]}')
#     plt.show()

# import random

# # 테스트 데이터셋에서 무작위로 이미지 선택
# random_index = random.randint(0, len(test_set) - 1)
# image_path = test_set.image_folder[random_index]
# image_path = os.path.join('/content/drive/MyDrive/datasets/test', image_path)

# # GradCAM 적용 함수 정의 (앞서 정의한 GradCAM 클래스와 apply_gradcam 함수)
# class_idx = test_set.__getitem__(random_index)[1]  # 이미지의 실제 클래스 인덱스
# target_layers = model.layer4[-1].to(DEVICE).conv2
# apply_gradcam(image_path, model, target_layers, classes)  # classes 변수에는 클래스 이름 목록을 할당
